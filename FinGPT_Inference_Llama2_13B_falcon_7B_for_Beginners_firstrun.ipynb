# %% [markdown]
# <a href="https://colab.research.google.com/github/AI4Finance-Foundation/FinGPT/blob/master/FinGPT_Inference_Llama2_13B_falcon_7B_for_Beginners.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install transformers==4.41.0 peft==0.5.0
# !pip install sentencepiece
# !pip install accelerate
# !pip install torch
# !pip install peft
# !pip install datasets
# !pip install bitsandbytes
# Out:
# Requirement already satisfied: transformers==4.41.0 in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (4.41.0)
# Collecting peft==0.5.0
#   Using cached peft-0.5.0-py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: filelock in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from transformers==4.41.0) (3.13.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.0 in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from transformers==4.41.0) (0.23.0)
# Requirement already satisfied: numpy>=1.17 in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from transformers==4.41.0) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from transformers==4.41.0) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from transformers==4.41.0) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from transformers==4.41.0) (2024.5.15)
# Requirement already satisfied: requests in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from transformers==4.41.0) (2.31.0)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from transformers==4.41.0) (0.19.1)
# Requirement already satisfied: safetensors>=0.4.1 in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from transformers==4.41.0) (0.4.3)
# Requirement already satisfied: tqdm>=4.27 in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from transformers==4.41.0) (4.66.4)
# Requirement already satisfied: psutil in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from peft==0.5.0) (5.9.0)
# Requirement already satisfied: torch>=1.13.0 in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from peft==0.5.0) (2.3.0)
# Requirement already satisfied: accelerate in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from peft==0.5.0) (0.30.1)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from huggingface-hub<1.0,>=0.23.0->transformers==4.41.0) (2024.3.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from huggingface-hub<1.0,>=0.23.0->transformers==4.41.0) (4.11.0)
# Requirement already satisfied: sympy in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from torch>=1.13.0->peft==0.5.0) (1.12)
# Requirement already satisfied: networkx in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from torch>=1.13.0->peft==0.5.0) (3.1)
# Requirement already satisfied: jinja2 in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from torch>=1.13.0->peft==0.5.0) (3.1.3)
# Requirement already satisfied: mkl<=2021.4.0,>=2021.1.1 in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from torch>=1.13.0->peft==0.5.0) (2021.4.0)
# Requirement already satisfied: colorama in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from tqdm>=4.27->transformers==4.41.0) (0.4.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from requests->transformers==4.41.0) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from requests->transformers==4.41.0) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from requests->transformers==4.41.0) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from requests->transformers==4.41.0) (2024.2.2)
# Requirement already satisfied: intel-openmp==2021.* in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from mkl<=2021.4.0,>=2021.1.1->torch>=1.13.0->peft==0.5.0) (2021.4.0)
# Requirement already satisfied: tbb==2021.* in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from mkl<=2021.4.0,>=2021.1.1->torch>=1.13.0->peft==0.5.0) (2021.12.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from jinja2->torch>=1.13.0->peft==0.5.0) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from sympy->torch>=1.13.0->peft==0.5.0) (1.3.0)
# Using cached peft-0.5.0-py3-none-any.whl (85 kB)
# Installing collected packages: peft
#   Attempting uninstall: peft
#     Found existing installation: peft 0.11.1
#     Uninstalling peft-0.11.1:
#       Successfully uninstalled peft-0.11.1
# Successfully installed peft-0.5.0
# Requirement already satisfied: sentencepiece in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (0.2.0)
# Requirement already satisfied: accelerate in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (0.30.1)
# Requirement already satisfied: numpy>=1.17 in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from accelerate) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from accelerate) (23.2)
# Requirement already satisfied: psutil in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from accelerate) (5.9.0)
# Requirement already satisfied: pyyaml in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from accelerate) (6.0.1)
# Requirement already satisfied: torch>=1.10.0 in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from accelerate) (2.3.0)
# Requirement already satisfied: huggingface-hub in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from accelerate) (0.23.0)
# Requirement already satisfied: safetensors>=0.3.1 in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from accelerate) (0.4.3)
# Requirement already satisfied: filelock in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from torch>=1.10.0->accelerate) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from torch>=1.10.0->accelerate) (4.11.0)
# Requirement already satisfied: sympy in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from torch>=1.10.0->accelerate) (1.12)
# Requirement already satisfied: networkx in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from torch>=1.10.0->accelerate) (3.1)
# Requirement already satisfied: jinja2 in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from torch>=1.10.0->accelerate) (3.1.3)
# Requirement already satisfied: fsspec in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from torch>=1.10.0->accelerate) (2024.3.1)
# Requirement already satisfied: mkl<=2021.4.0,>=2021.1.1 in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from torch>=1.10.0->accelerate) (2021.4.0)
# Requirement already satisfied: requests in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from huggingface-hub->accelerate) (2.31.0)
# Requirement already satisfied: tqdm>=4.42.1 in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from huggingface-hub->accelerate) (4.66.4)
# Requirement already satisfied: intel-openmp==2021.* in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from mkl<=2021.4.0,>=2021.1.1->torch>=1.10.0->accelerate) (2021.4.0)
# Requirement already satisfied: tbb==2021.* in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from mkl<=2021.4.0,>=2021.1.1->torch>=1.10.0->accelerate) (2021.12.0)
# Requirement already satisfied: colorama in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from tqdm>=4.42.1->huggingface-hub->accelerate) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from jinja2->torch>=1.10.0->accelerate) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from requests->huggingface-hub->accelerate) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from requests->huggingface-hub->accelerate) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from requests->huggingface-hub->accelerate) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from requests->huggingface-hub->accelerate) (2024.2.2)
# Requirement already satisfied: mpmath>=0.19 in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from sympy->torch>=1.10.0->accelerate) (1.3.0)
# Requirement already satisfied: torch in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (2.3.0)
# Requirement already satisfied: filelock in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from torch) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from torch) (4.11.0)
# Requirement already satisfied: sympy in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from torch) (1.12)
# Requirement already satisfied: networkx in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from torch) (3.1)
# Requirement already satisfied: jinja2 in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from torch) (3.1.3)
# Requirement already satisfied: fsspec in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from torch) (2024.3.1)
# Requirement already satisfied: mkl<=2021.4.0,>=2021.1.1 in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from torch) (2021.4.0)
# Requirement already satisfied: intel-openmp==2021.* in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from mkl<=2021.4.0,>=2021.1.1->torch) (2021.4.0)
# Requirement already satisfied: tbb==2021.* in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from mkl<=2021.4.0,>=2021.1.1->torch) (2021.12.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from jinja2->torch) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from sympy->torch) (1.3.0)
# Requirement already satisfied: peft in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (0.5.0)
# Requirement already satisfied: numpy>=1.17 in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from peft) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from peft) (23.2)
# Requirement already satisfied: psutil in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from peft) (5.9.0)
# Requirement already satisfied: pyyaml in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from peft) (6.0.1)
# Requirement already satisfied: torch>=1.13.0 in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from peft) (2.3.0)
# Requirement already satisfied: transformers in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from peft) (4.41.0)
# Requirement already satisfied: tqdm in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from peft) (4.66.4)
# Requirement already satisfied: accelerate in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from peft) (0.30.1)
# Requirement already satisfied: safetensors in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from peft) (0.4.3)
# Requirement already satisfied: filelock in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from torch>=1.13.0->peft) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from torch>=1.13.0->peft) (4.11.0)
# Requirement already satisfied: sympy in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from torch>=1.13.0->peft) (1.12)
# Requirement already satisfied: networkx in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from torch>=1.13.0->peft) (3.1)
# Requirement already satisfied: jinja2 in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from torch>=1.13.0->peft) (3.1.3)
# Requirement already satisfied: fsspec in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from torch>=1.13.0->peft) (2024.3.1)
# Requirement already satisfied: mkl<=2021.4.0,>=2021.1.1 in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from torch>=1.13.0->peft) (2021.4.0)
# Requirement already satisfied: huggingface-hub in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from accelerate->peft) (0.23.0)
# Requirement already satisfied: colorama in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from tqdm->peft) (0.4.6)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from transformers->peft) (2024.5.15)
# Requirement already satisfied: requests in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from transformers->peft) (2.31.0)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from transformers->peft) (0.19.1)
# Requirement already satisfied: intel-openmp==2021.* in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from mkl<=2021.4.0,>=2021.1.1->torch>=1.13.0->peft) (2021.4.0)
# Requirement already satisfied: tbb==2021.* in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from mkl<=2021.4.0,>=2021.1.1->torch>=1.13.0->peft) (2021.12.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from jinja2->torch>=1.13.0->peft) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from requests->transformers->peft) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from requests->transformers->peft) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from requests->transformers->peft) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from requests->transformers->peft) (2024.2.2)
# Requirement already satisfied: mpmath>=0.19 in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from sympy->torch>=1.13.0->peft) (1.3.0)
# Requirement already satisfied: datasets in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (2.19.1)
# Requirement already satisfied: filelock in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from datasets) (3.13.1)
# Requirement already satisfied: numpy>=1.17 in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from datasets) (1.26.4)
# Requirement already satisfied: pyarrow>=12.0.0 in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from datasets) (16.1.0)
# Requirement already satisfied: pyarrow-hotfix in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from datasets) (0.6)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from datasets) (2.2.2)
# Requirement already satisfied: requests>=2.19.0 in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from datasets) (2.31.0)
# Requirement already satisfied: tqdm>=4.62.1 in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from datasets) (4.66.4)
# Requirement already satisfied: xxhash in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from datasets) (3.4.1)
# Requirement already satisfied: multiprocess in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec<=2024.3.1,>=2023.1.0 in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from fsspec[http]<=2024.3.1,>=2023.1.0->datasets) (2024.3.1)
# Requirement already satisfied: aiohttp in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from datasets) (3.9.5)
# Requirement already satisfied: huggingface-hub>=0.21.2 in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from datasets) (0.23.0)
# Requirement already satisfied: packaging in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from datasets) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from datasets) (6.0.1)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from aiohttp->datasets) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from aiohttp->datasets) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from aiohttp->datasets) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from aiohttp->datasets) (1.9.4)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from huggingface-hub>=0.21.2->datasets) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from requests>=2.19.0->datasets) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from requests>=2.19.0->datasets) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from requests>=2.19.0->datasets) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from requests>=2.19.0->datasets) (2024.2.2)
# Requirement already satisfied: colorama in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from tqdm>=4.62.1->datasets) (0.4.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: six>=1.5 in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)
# Requirement already satisfied: bitsandbytes in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (0.43.1)
# Requirement already satisfied: torch in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from bitsandbytes) (2.3.0)
# Requirement already satisfied: numpy in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from bitsandbytes) (1.26.4)
# Requirement already satisfied: filelock in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from torch->bitsandbytes) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from torch->bitsandbytes) (4.11.0)
# Requirement already satisfied: sympy in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from torch->bitsandbytes) (1.12)
# Requirement already satisfied: networkx in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from torch->bitsandbytes) (3.1)
# Requirement already satisfied: jinja2 in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from torch->bitsandbytes) (3.1.3)
# Requirement already satisfied: fsspec in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from torch->bitsandbytes) (2024.3.1)
# Requirement already satisfied: mkl<=2021.4.0,>=2021.1.1 in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from torch->bitsandbytes) (2021.4.0)
# Requirement already satisfied: intel-openmp==2021.* in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from mkl<=2021.4.0,>=2021.1.1->torch->bitsandbytes) (2021.4.0)
# Requirement already satisfied: tbb==2021.* in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from mkl<=2021.4.0,>=2021.1.1->torch->bitsandbytes) (2021.12.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from jinja2->torch->bitsandbytes) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from sympy->torch->bitsandbytes) (1.3.0)

# %%
from platform import python_version
print(python_version())
# Out:
# 3.12.3

# %%
import transformers
print(transformers.__version__)
# Out:
# 4.41.0

# %%
### for the `load_in_8bit=True` error
# !pip install protobuf transformers==4.41.0 cpm_kernels torch>=2.0 gradio mdtex2html sentencepiece accelerate

# %%
# !pip install -U setuptools
# Out:
# Requirement already satisfied: setuptools in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (69.5.1)

# %%
# !pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (2.16.1)
# Requirement already satisfied: tensorflow-intel==2.16.1 in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from tensorflow) (2.16.1)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (3.11.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (18.1.1)
# Requirement already satisfied: ml-dtypes~=0.3.1 in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (0.3.2)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (3.3.0)
# Requirement already satisfied: packaging in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (23.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (4.25.3)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (2.31.0)
# Requirement already satisfied: setuptools in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (69.5.1)
# Requirement already satisfied: six>=1.12.0 in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (4.11.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (1.16.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (1.63.0)
# Requirement already satisfied: tensorboard<2.17,>=2.16 in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (2.16.2)
# Requirement already satisfied: keras>=3.0.0 in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (3.3.3)
# Requirement already satisfied: numpy<2.0.0,>=1.26.0 in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (1.26.4)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.16.1->tensorflow) (0.43.0)
# Requirement already satisfied: rich in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow) (13.7.1)
# Requirement already satisfied: namex in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow) (0.0.8)
# Requirement already satisfied: optree in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow) (0.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.16.1->tensorflow) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.16.1->tensorflow) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.16.1->tensorflow) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.16.1->tensorflow) (2024.2.2)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from tensorboard<2.17,>=2.16->tensorflow-intel==2.16.1->tensorflow) (3.6)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from tensorboard<2.17,>=2.16->tensorflow-intel==2.16.1->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from tensorboard<2.17,>=2.16->tensorflow-intel==2.16.1->tensorflow) (3.0.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.17,>=2.16->tensorflow-intel==2.16.1->tensorflow) (2.1.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from rich->keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from rich->keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow) (0.1.2)

# %%
# !nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2024 NVIDIA Corporation
# Built on Thu_Mar_28_02:30:10_Pacific_Daylight_Time_2024
# Cuda compilation tools, release 12.4, V12.4.131
# Build cuda_12.4.r12.4/compiler.34097967_0

# %%
# !pip install torch
# Out:
# Requirement already satisfied: torch in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (2.3.0)
# Requirement already satisfied: filelock in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from torch) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from torch) (4.11.0)
# Requirement already satisfied: sympy in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from torch) (1.12)
# Requirement already satisfied: networkx in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from torch) (3.1)
# Requirement already satisfied: jinja2 in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from torch) (3.1.3)
# Requirement already satisfied: fsspec in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from torch) (2024.3.1)
# Requirement already satisfied: mkl<=2021.4.0,>=2021.1.1 in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from torch) (2021.4.0)
# Requirement already satisfied: intel-openmp==2021.* in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from mkl<=2021.4.0,>=2021.1.1->torch) (2021.4.0)
# Requirement already satisfied: tbb==2021.* in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from mkl<=2021.4.0,>=2021.1.1->torch) (2021.12.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from jinja2->torch) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from sympy->torch) (1.3.0)

# %%
import torch
print(torch.__version__)
# Out:
# 2.3.0

# %%
pip install packaging
# Out:
# Requirement already satisfied: packaging in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (23.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
ninja --version
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 ninja --version
#
# NameError: name 'ninja' is not defined

# %%
# !pip uninstall -y ninja
# !pip install ninja
# Out:
# Found existing installation: ninja 1.11.1.1
# Uninstalling ninja-1.11.1.1:
#   Successfully uninstalled ninja-1.11.1.1
# Collecting ninja
#   Using cached ninja-1.11.1.1-py2.py3-none-win_amd64.whl.metadata (5.4 kB)
# Using cached ninja-1.11.1.1-py2.py3-none-win_amd64.whl (312 kB)
# Installing collected packages: ninja
# Successfully installed ninja-1.11.1.1

# %%
# !pip install flash_attn --no-build-isolation
# Out:
# Collecting flash_attn
#   Using cached flash_attn-2.5.8.tar.gz (2.5 MB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'error'
#   error: subprocess-exited-with-error
#
#   python setup.py egg_info did not run successfully.
#   exit code: 1
#
#   [14 lines of output]
#   Traceback (most recent call last):
#     File "<string>", line 2, in <module>
#     File "<pip-setuptools-caller>", line 34, in <module>
#     File "C:\Users\F21Z\AppData\Local\Temp\pip-install-n2190d1x\flash-attn_e7d472765a6c4d6680ff27d9ae97d085\setup.py", line 95, in <module>
#       subprocess.run(["git", "submodule", "update", "--init", "csrc/cutlass"])
#     File "C:\Users\F21Z\anaconda3\envs\for_fingpt\Lib\subprocess.py", line 548, in run
#       with Popen(*popenargs, **kwargs) as process:
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     File "C:\Users\F21Z\anaconda3\envs\for_fingpt\Lib\subprocess.py", line 1026, in __init__
#       self._execute_child(args, executable, preexec_fn, close_fds,
#     File "C:\Users\F21Z\anaconda3\envs\for_fingpt\Lib\subprocess.py", line 1538, in _execute_child
#       hp, ht, pid, tid = _winapi.CreateProcess(executable, args,
#                          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   FileNotFoundError: [WinError 2] The system cannot find the file specified
#   [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: metadata-generation-failed
#
# Encountered error while generating package metadata.
#
# See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.

# %%
# !pip install exllamav2
# Out:
# Collecting exllamav2
#   Downloading exllamav2-0.0.21-py3-none-any.whl.metadata (422 bytes)
# Requirement already satisfied: pandas in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from exllamav2) (2.2.2)
# Collecting ninja (from exllamav2)
#   Downloading ninja-1.11.1.1-py2.py3-none-win_amd64.whl.metadata (5.4 kB)
# Collecting fastparquet (from exllamav2)
#   Downloading fastparquet-2024.2.0-cp312-cp312-win_amd64.whl.metadata (4.2 kB)
# Requirement already satisfied: torch>=2.2.0 in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from exllamav2) (2.3.0)
# Requirement already satisfied: safetensors>=0.3.2 in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from exllamav2) (0.4.3)
# Requirement already satisfied: sentencepiece>=0.1.97 in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from exllamav2) (0.2.0)
# Requirement already satisfied: pygments in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from exllamav2) (2.15.1)
# Requirement already satisfied: websockets in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from exllamav2) (11.0.3)
# Requirement already satisfied: regex in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from exllamav2) (2024.5.15)
# Requirement already satisfied: numpy in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from exllamav2) (1.26.4)
# Requirement already satisfied: filelock in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from torch>=2.2.0->exllamav2) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from torch>=2.2.0->exllamav2) (4.11.0)
# Requirement already satisfied: sympy in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from torch>=2.2.0->exllamav2) (1.12)
# Requirement already satisfied: networkx in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from torch>=2.2.0->exllamav2) (3.1)
# Requirement already satisfied: jinja2 in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from torch>=2.2.0->exllamav2) (3.1.3)
# Requirement already satisfied: fsspec in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from torch>=2.2.0->exllamav2) (2024.3.1)
# Requirement already satisfied: mkl<=2021.4.0,>=2021.1.1 in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from torch>=2.2.0->exllamav2) (2021.4.0)
# Collecting cramjam>=2.3 (from fastparquet->exllamav2)
#   Downloading cramjam-2.8.3-cp312-none-win_amd64.whl.metadata (4.3 kB)
# Requirement already satisfied: packaging in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from fastparquet->exllamav2) (23.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from pandas->exllamav2) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from pandas->exllamav2) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from pandas->exllamav2) (2024.1)
# Requirement already satisfied: intel-openmp==2021.* in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from mkl<=2021.4.0,>=2021.1.1->torch>=2.2.0->exllamav2) (2021.4.0)
# Requirement already satisfied: tbb==2021.* in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from mkl<=2021.4.0,>=2021.1.1->torch>=2.2.0->exllamav2) (2021.12.0)
# Requirement already satisfied: six>=1.5 in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from python-dateutil>=2.8.2->pandas->exllamav2) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from jinja2->torch>=2.2.0->exllamav2) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from sympy->torch>=2.2.0->exllamav2) (1.3.0)
# Downloading exllamav2-0.0.21-py3-none-any.whl (222 kB)
#    ---------------------------------------- 0.0/222.1 kB ? eta -:--:--
#    --- ----------------------------------- 20.5/222.1 kB 640.0 kB/s eta 0:00:01
#    ------- ------------------------------- 41.0/222.1 kB 653.6 kB/s eta 0:00:01
#    ---------------------- ----------------- 122.9/222.1 kB 1.2 MB/s eta 0:00:01
#    ---------------------------------------- 222.1/222.1 kB 1.5 MB/s eta 0:00:00
# Downloading fastparquet-2024.2.0-cp312-cp312-win_amd64.whl (669 kB)
#    ---------------------------------------- 0.0/669.7 kB ? eta -:--:--
#    -------------- ------------------------- 235.5/669.7 kB 4.8 MB/s eta 0:00:01
#    -------------------- ------------------- 348.2/669.7 kB 3.6 MB/s eta 0:00:01
#    ----------------------------- ---------- 501.8/669.7 kB 3.5 MB/s eta 0:00:01
#    ------------------------------------- -- 634.9/669.7 kB 3.6 MB/s eta 0:00:01
#    ---------------------------------------- 669.7/669.7 kB 3.2 MB/s eta 0:00:00
# Downloading ninja-1.11.1.1-py2.py3-none-win_amd64.whl (312 kB)
#    ---------------------------------------- 0.0/313.0 kB ? eta -:--:--
#    ----------------------- ---------------- 184.3/313.0 kB 5.6 MB/s eta 0:00:01
#    ---------------------------------------- 313.0/313.0 kB 4.9 MB/s eta 0:00:00
# Downloading cramjam-2.8.3-cp312-none-win_amd64.whl (1.6 MB)
#    ---------------------------------------- 0.0/1.6 MB ? eta -:--:--
#    ----- ---------------------------------- 0.2/1.6 MB 7.6 MB/s eta 0:00:01
#    ---------- ----------------------------- 0.4/1.6 MB 5.5 MB/s eta 0:00:01
#    -------------- ------------------------- 0.6/1.6 MB 5.5 MB/s eta 0:00:01
#    -------------------- ------------------- 0.8/1.6 MB 5.3 MB/s eta 0:00:01
#    ------------------------- -------------- 1.0/1.6 MB 5.1 MB/s eta 0:00:01
#    -------------------------------- ------- 1.3/1.6 MB 5.2 MB/s eta 0:00:01
#    ------------------------------------ --- 1.5/1.6 MB 5.0 MB/s eta 0:00:01
#    ------------------------------------- -- 1.5/1.6 MB 4.7 MB/s eta 0:00:01
#    ---------------------------------------- 1.6/1.6 MB 4.6 MB/s eta 0:00:00
# Installing collected packages: ninja, cramjam, fastparquet, exllamav2
# Successfully installed cramjam-2.8.3 exllamav2-0.0.21 fastparquet-2024.2.0 ninja-1.11.1.1

# %%
# !pip install transformers -U
# Out:
# Requirement already satisfied: transformers in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (4.41.0)
# Requirement already satisfied: filelock in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from transformers) (3.13.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.0 in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from transformers) (0.23.0)
# Requirement already satisfied: numpy>=1.17 in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from transformers) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from transformers) (2024.5.15)
# Requirement already satisfied: requests in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from transformers) (2.31.0)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from transformers) (0.19.1)
# Requirement already satisfied: safetensors>=0.4.1 in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from transformers) (0.4.3)
# Requirement already satisfied: tqdm>=4.27 in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from transformers) (4.66.4)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from huggingface-hub<1.0,>=0.23.0->transformers) (2024.3.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from huggingface-hub<1.0,>=0.23.0->transformers) (4.11.0)
# Requirement already satisfied: colorama in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from requests->transformers) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from requests->transformers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from requests->transformers) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (from requests->transformers) (2024.2.2)

# %%
# !pip install --upgrade pip setuptools wheel
# Out:
# Requirement already satisfied: pip in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (24.0)
# Requirement already satisfied: setuptools in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (69.5.1)
# Requirement already satisfied: wheel in c:\users\f21z\anaconda3\envs\for_fingpt\lib\site-packages (0.43.0)

# %% [markdown]
# ## Inference with Single Task: Sentiment

# %%
from transformers import AutoModel, AutoTokenizer, AutoModelForCausalLM, LlamaForCausalLM, LlamaTokenizerFast
from peft import PeftModel  # 0.5.0

# %%
# Load Models
base_model = "NousResearch/Llama-2-13b-hf"
peft_model = "FinGPT/fingpt-sentiment_llama2-13b_lora"
tokenizer = LlamaTokenizerFast.from_pretrained(base_model, trust_remote_code=True)
tokenizer.pad_token = tokenizer.eos_token
model = LlamaForCausalLM.from_pretrained(base_model, trust_remote_code=True, device_map = "cuda:0", load_in_8bit = True,)
model = PeftModel.from_pretrained(model, peft_model)
model = model.eval()
# Out:
# The argument `trust_remote_code` is to be used with Auto classes. It has no effect here and is ignored.
# The `load_in_4bit` and `load_in_8bit` arguments are deprecated and will be removed in the future versions. Please, pass a `BitsAndBytesConfig` object in `quantization_config` argument instead.
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# C:\Users\F21Z\anaconda3\envs\for_fingpt\Lib\site-packages\transformers\generation\configuration_utils.py:515: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0.9` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`. This was detected when initializing the generation config instance, which means the corresponding file may hold incorrect parameterization and should be fixed.
#   warnings.warn(
# C:\Users\F21Z\anaconda3\envs\for_fingpt\Lib\site-packages\transformers\generation\configuration_utils.py:520: UserWarning: `do_sample` is set to `False`. However, `top_p` is set to `0.6` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `top_p`. This was detected when initializing the generation config instance, which means the corresponding file may hold incorrect parameterization and should be fixed.
#   warnings.warn(
# C:\Users\F21Z\anaconda3\envs\for_fingpt\Lib\site-packages\transformers\generation\configuration_utils.py:515: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0.9` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`.
#   warnings.warn(
# C:\Users\F21Z\anaconda3\envs\for_fingpt\Lib\site-packages\transformers\generation\configuration_utils.py:520: UserWarning: `do_sample` is set to `False`. However, `top_p` is set to `0.6` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `top_p`.
#   warnings.warn(
# adapter_config.json:   0%|          | 0.00/462 [00:00<?, ?B/s]
# C:\Users\F21Z\anaconda3\envs\for_fingpt\Lib\site-packages\huggingface_hub\file_download.py:157: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\F21Z\.cache\huggingface\hub\models--FinGPT--fingpt-sentiment_llama2-13b_lora. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to see activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# adapter_model.bin:   0%|          | 0.00/19.7M [00:00<?, ?B/s]

# %%
# Make prompts
prompt = [
'''Instruction: What is the sentiment of this news? Please choose an answer from {negative/neutral/positive}
Input: FINANCING OF ASPOCOMP 'S GROWTH Aspocomp is aggressively pursuing its growth strategy by increasingly focusing on technologically more demanding HDI printed circuit boards PCBs .
Answer: ''',
'''Instruction: What is the sentiment of this news? Please choose an answer from {negative/neutral/positive}
Input: According to Gran , the company has no plans to move all production to Russia , although that is where the company is growing .
Answer: ''',
'''Instruction: What is the sentiment of this news? Please choose an answer from {negative/neutral/positive}
Input: A tinyurl link takes users to a scamming site promising that users can earn thousands of dollars by becoming a Google ( NASDAQ : GOOG ) Cash advertiser .
Answer: ''',
]

# Generate results
tokens = tokenizer(prompt, return_tensors='pt', padding=True, max_length=512)
res = model.generate(**tokens, max_length=512)
res_sentences = [tokenizer.decode(i) for i in res]
out_text = [o.split("Answer: ")[1] for o in res_sentences]

# show results
for sentiment in out_text:
    print(sentiment)

# Output:
# positive
# neutral
# negative
# Out:
# C:\Users\F21Z\anaconda3\envs\for_fingpt\Lib\site-packages\transformers\tokenization_utils_base.py:2717: UserWarning: `max_length` is ignored when `padding`=`True` and there is no truncation strategy. To pad to max length, use `padding='max_length'`.
#   warnings.warn(
# C:\Users\F21Z\anaconda3\envs\for_fingpt\Lib\site-packages\transformers\generation\utils.py:1637: UserWarning: You are calling .generate() with the `input_ids` being on a device type different than your model's device. `input_ids` is on cpu, whereas the model is on cuda. You may experience unexpected behaviors or slower generation. Please make sure that you have put `input_ids` to the correct device by calling for example input_ids = input_ids.to('cuda') before running `.generate()`.
#   warnings.warn(
# C:\Users\F21Z\anaconda3\envs\for_fingpt\Lib\site-packages\transformers\models\llama\modeling_llama.py:649: UserWarning: 1Torch was not compiled with flash attention. (Triggered internally at C:\cb\pytorch_1000000000000\work\aten\src\ATen\native\transformers\cuda\sdp_utils.cpp:455.)
#   attn_output = torch.nn.functional.scaled_dot_product_attention(
#  positive</s>
#  neutral</s>
#  negative</s>

# %% [markdown]
# ## Inference with Multi-Task
# * Please Restart runtime, the memory is not enough to run two tasks

# %%
from transformers import AutoModel, AutoTokenizer, AutoModelForCausalLM, LlamaForCausalLM, LlamaTokenizerFast
from peft import PeftModel  # 0.5.0

# %%
import os
import datasets


template_dict = {
    'default': 'Instruction: {instruction}\nInput: {input}\nAnswer: '
}

lora_module_dict = {
    'chatglm2': ['query_key_value'],
    'falcon': ['query_key_value'],
    'bloom': ['query_key_value'],
    'internlm': ['q_proj', 'k_proj', 'v_proj'],
    'llama2': ['q_proj', 'k_proj', 'v_proj'],
    'qwen': ["c_attn"],
    'mpt': ['Wqkv'],
}


def get_prompt(template, instruction, input):

    if instruction:
        return template_dict[template].format(instruction=instruction, input=input)
    else:
        return input


def test_mapping(args, feature):

    prompt = get_prompt(
        args.instruct_template,
        feature['instruction'],
        feature['input']
    )
    return {
        "prompt": prompt,
    }


def tokenize(args, tokenizer, feature):

    prompt = get_prompt(
        args.instruct_template,
        feature['instruction'],
        feature['input']
    )
    prompt_ids = tokenizer(
        prompt, padding=False,
        max_length=args.max_length, truncation=True
    )['input_ids']
    target_ids = tokenizer(
        feature['output'].strip(), padding=False,
        max_length=args.max_length, truncation=True,
        add_special_tokens=False
    )['input_ids']

    input_ids = prompt_ids + target_ids
    exceed_max_length = len(input_ids) >= args.max_length

    # Add EOS Token
    if input_ids[-1] != tokenizer.eos_token_id and not exceed_max_length:
        input_ids.append(tokenizer.eos_token_id)

    label_ids = [tokenizer.pad_token_id] * len(prompt_ids) + input_ids[len(prompt_ids):]

    return {
        "input_ids": input_ids,
        "labels": label_ids,
        "exceed_max_length": exceed_max_length
    }


def parse_model_name(name, from_remote=False):

    if name == 'chatglm2':
        return 'THUDM/chatglm2-6b' if from_remote else 'base_models/chatglm2-6b'
    elif name == 'llama2':
        return 'meta-llama/Llama-2-7b-hf' if from_remote else 'base_models/Llama-2-7b-hf'
        # return 'NousResearch/Llama-2-7b-hf' if from_remote else 'base_models/Llama-2-7b-hf-nous'
    elif name == 'falcon':
        return 'tiiuae/falcon-7b' if from_remote else 'base_models/falcon-7b'
    elif name == 'internlm':
        return 'internlm/internlm-7b' if from_remote else 'base_models/internlm-7b'
    elif name == 'qwen':
        return 'Qwen/Qwen-7B' if from_remote else 'base_models/Qwen-7B'
    elif name == 'mpt':
        return 'cekal/mpt-7b-peft-compatible' if from_remote else 'base_models/mpt-7b-peft-compatible'
        # return 'mosaicml/mpt-7b' if from_remote else 'base_models/mpt-7b'
    elif name == 'bloom':
        return 'bigscience/bloom-7b1' if from_remote else 'base_models/bloom-7b1'
    else:
        raise ValueError(f"Undefined base model {name}")


def load_dataset(names, from_remote=False):
    dataset_names = [d for d in names.split(',')]
    dataset_list = []
    for name in dataset_names:
        rep = 1
        if not os.path.exists(name):
            rep = int(name.split('*')[1]) if '*' in name else 1
            name = ('FinGPT/fingpt-' if from_remote else 'data/fingpt-') + name.split('*')[0]
        tmp_dataset = datasets.load_from_disk(name)
        if 'test' not in tmp_dataset:
            tmp_dataset = tmp_dataset.train_test_split(0.2, shuffle=True, seed=42)

        dataset_list.extend([tmp_dataset] * rep)
    return dataset_list

# %%
def load_model(base_model, peft_model, from_remote=True):

    model_name = parse_model_name(base_model, from_remote)

    model = AutoModelForCausalLM.from_pretrained(
        model_name, trust_remote_code=True,
        device_map="auto",
    )
    model.model_parallel = True

    tokenizer = AutoTokenizer.from_pretrained(model_name, trust_remote_code=True)

    tokenizer.padding_side = "left"
    if base_model == 'qwen':
        tokenizer.eos_token_id = tokenizer.convert_tokens_to_ids('<|endoftext|>')
        tokenizer.pad_token_id = tokenizer.convert_tokens_to_ids('<|extra_0|>')
    if not tokenizer.pad_token or tokenizer.pad_token_id == tokenizer.eos_token_id:
        tokenizer.add_special_tokens({'pad_token': '[PAD]'})
        model.resize_token_embeddings(len(tokenizer))

    model = PeftModel.from_pretrained(model, peft_model)
    model = model.eval()
    return model, tokenizer


def test_demo(model, tokenizer):

    for task_name, input, instruction in zip(demo_tasks, demo_inputs, demo_instructions):
        prompt = 'Instruction: {instruction}\nInput: {input}\nAnswer: '.format(
            input=input,
            instruction=instruction
        )
        inputs = tokenizer(
            prompt, return_tensors='pt',
            padding=True, max_length=512,
            return_token_type_ids=False
        )
        inputs = {key: value.to(model.device) for key, value in inputs.items()}
        res = model.generate(
            **inputs, max_length=512, do_sample=False,
            eos_token_id=tokenizer.eos_token_id
        )
        output = tokenizer.decode(res[0], skip_special_tokens=True)
        print(f"\n==== {task_name} ====\n")
        print(output)

# %%
FROM_REMOTE=True

base_model = 'falcon'
peft_model = 'FinGPT/fingpt-mt_falcon-7b_lora' if FROM_REMOTE else 'finetuned_models/MT-falcon-linear_202309210126'

model, tokenizer = load_model(base_model, peft_model, FROM_REMOTE)
# Out:
# config.json:   0%|          | 0.00/1.05k [00:00<?, ?B/s]
# C:\Users\F21Z\anaconda3\envs\for_fingpt\Lib\site-packages\huggingface_hub\file_download.py:157: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\F21Z\.cache\huggingface\hub\models--tiiuae--falcon-7b. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to see activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# configuration_falcon.py:   0%|          | 0.00/7.16k [00:00<?, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/tiiuae/falcon-7b:
# - configuration_falcon.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
#
# WARNING: You are currently loading Falcon using legacy code contained in the model repository. Falcon has now been fully ported into the Hugging Face transformers library. For the most up-to-date and high-performance version of the Falcon model code, please update to the latest version of transformers and then load the model without the trust_remote_code=True argument.
# modeling_falcon.py:   0%|          | 0.00/56.9k [00:00<?, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/tiiuae/falcon-7b:
# - modeling_falcon.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# pytorch_model.bin.index.json:   0%|          | 0.00/16.9k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/2 [00:00<?, ?it/s]
# pytorch_model-00001-of-00002.bin:   0%|          | 0.00/9.95G [00:00<?, ?B/s]
# Error while downloading from https://cdn-lfs.huggingface.co/repos/80/bd/80bd1e4a99ab55602d887f91215879d76ac3e1b877b8f683477be2952b8cb778/1c4b989693576ce79edf5f8f1a2d199d66c1448d35a126e52ba09cb67ca5da39?response-content-disposition=attachment%3B+filename*%3DUTF-8%27%27pytorch_model-00001-of-00002.bin%3B+filename%3D%22pytorch_model-00001-of-00002.bin%22%3B&response-content-type=application%2Foctet-stream&Expires=1716297771&Policy=%7EcmVzcG9uc2UtY29udGVudC1kaXNwb3NpdGlvbj0qJnJlc3BvbnNlLWNvbnRlbnQtdHlwZT0qIn1dfQ__&Signature=EQYn5dnxA2wpTQERAD3Z%7EFPItuvEzjotlYgbO4GXkY48PMvADMbtNSPeoIvbBeJXM6FWMBLPi2UyKxvKGzCpwejcw8ZJl68ym3yLAl0M2pFWftamXgMFhHHZyHALbvx3Gn2oDdINGoGk-lDppqqLwKAIWFwxLuMLNFcojnll-dLsfTHxrP0N0Lm4MJCBoRxfGdIKKNu7IgnZk61zTt%7E9j4w0K-L3T4bHOYlmQiOfoV-OcjNXEou26ZqMT-iXk2TaSCO%7EYe7yShXcilV6%7EU5hiTNJ1QyHPHB9sw0J5mPffCDlhqhSpNFepbVf78hIIzRDC9AD0tpxN8cTNgDx6GBheA__&Key-Pair-Id=KVTP0A1DKRTAX: HTTPSConnectionPool(host='cdn-lfs.huggingface.co', port=443): Read timed out.
# Trying to resume download...
# pytorch_model-00001-of-00002.bin:  46%|####6     | 4.59G/9.95G [00:00<?, ?B/s]

# %%
demo_tasks = [
    'Financial Sentiment Analysis',
    'Financial Relation Extraction',
    'Financial Headline Classification',
    'Financial Named Entity Recognition',
]
demo_inputs = [
    "Glaxo's ViiV Healthcare Signs China Manufacturing Deal With Desano",
    "Apple Inc Chief Executive Steve Jobs sought to soothe investor concerns about his health on Monday, saying his weight loss was caused by a hormone imbalance that is relatively simple to treat.",
    'gold trades in red in early trade; eyes near-term range at rs 28,300-28,600',
    'This LOAN AND SECURITY AGREEMENT dated January 27 , 1999 , between SILICON VALLEY BANK (" Bank "), a California - chartered bank with its principal place of business at 3003 Tasman Drive , Santa Clara , California 95054 with a loan production office located at 40 William St ., Ste .',
]
demo_instructions = [
    'What is the sentiment of this news? Please choose an answer from {negative/neutral/positive}.',
    'Given phrases that describe the relationship between two words/phrases as options, extract the word/phrase pair and the corresponding lexical relationship between them from the input text. The output format should be "relation1: word1, word2; relation2: word3, word4". Options: product/material produced, manufacturer, distributed by, industry, position held, original broadcaster, owned by, founded by, distribution format, headquarters location, stock exchange, currency, parent organization, chief executive officer, director/manager, owner of, operator, member of, employer, chairperson, platform, subsidiary, legal form, publisher, developer, brand, business division, location of formation, creator.',
    'Does the news headline talk about price going up? Please choose an answer from {Yes/No}.',
    'Please extract entities and their types from the input sentence, entity types should be chosen from {person/organization/location}.',
]

# %%
test_demo(model, tokenizer)
